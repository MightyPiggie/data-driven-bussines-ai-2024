# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\GitHub\jaar 2\groeps project trein\dataset-prorail-clean-2.csv")
df.head()
# Out:
# C:\Users\casja\AppData\Local\Temp\ipykernel_1032\896878633.py:1: DtypeWarning: Columns (0,8,11,12,13,17,20,21,26,37,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\GitHub\jaar 2\groeps project trein\dataset-prorail-clean-2.csv")
#   Unnamed: 0  #stm_sap_meldnr  stm_mon_nr stm_vl_post     stm_sap_meld_ddt  \
# 0          0                0         NaN         NaN                  NaN
# 1          1         50053211         0.0         NaN  02/01/2006 09:00:00
# 2          2         50053213        48.0          GN  02/01/2006 12:35:00
# 3          3         50053214        72.0          ZL  02/01/2006 16:40:00
# 4          4         50053215        96.0          ZL  02/01/2006 22:30:00
#
#                               stm_sap_meldtekst_lang  \
# 0                                                NaN
# 1   Logboeknr  Geeltje  :   49 Tijd: 0900   VL-Po...
# 2   Logboeknr  RBV  :   48 Tijd: 1235   VL-Post: ...
# 3   Logboeknr  RBV  :   72 Tijd: 1640   VL-Post: ...
# 4   Logboeknr  RBV  :   96 Tijd: 2230   VL-Post: ...
#
#                           stm_sap_meldtekst stm_geo_mld stm_equipm_nr_mld  \
# 0                                       NaN         NaN               NaN
# 1     Logboeknr  Geeltje  :   49 Tijd: 0900       624.0               NaN
# 2  Logboeknr  RBV  :   48 Tijd: 1235   VL-P       201.0               NaN
# 3  Logboeknr  RBV  :   72 Tijd: 1640   VL-P        25.0               NaN
# 4  Logboeknr  RBV  :   96 Tijd: 2230   VL-P        12.0               NaN
#
#   stm_equipm_soort_mld  ... stm_fh_tijd stm_fh_duur stm_sap_storeinddatum  \
# 0                  NaN  ...         NaN         NaN                   NaN
# 1                  NaN  ...    09:00:00         0.0            02/01/2006
# 2                  NaN  ...    13:26:00        51.0            02/01/2006
# 3                  NaN  ...    17:20:00        40.0            02/01/2006
# 4                  NaN  ...    22:36:00         6.0            02/01/2006
#
#   stm_sap_storeindtijd            stm_oorz_tekst_kort stm_schade_verhaalb_jn  \
# 0                  NaN                            NaN                    NaN
# 1             09:00:00                            NaN                    NaN
# 2             13:26:00       schapen op de spoorbaan!                    NaN
# 3             17:20:00          Persoon langs de baan                    NaN
# 4             22:36:00   Bijna aanrijding met persoon                    NaN
#
#   stm_pplg_van stm_pplg_naar stm_dstrglp_van stm_dstrglp_naar
# 0          NaN           NaN             NaN              NaN
# 1          NaN           NaN             NaN              NaN
# 2          NaN           NaN              Lp              Apg
# 3          NaN           NaN             Hgl              NaN
# 4          NaN           NaN             Hgv              NaN
#
# [5 rows x 61 columns]

# %%
data = pd.read_csv(r"C:\GitHub\jaar 2\groeps project trein\dataset-prorail-clean-2.csv")
single_or_empty_columns = {col: data[col].unique() for col in data.columns if data[col].nunique() == 1 or data[col].isna().all()}

if single_or_empty_columns:
    print("Columns with a single unique value or that are entirely empty:")
    for col, values in single_or_empty_columns.items():
        if data[col].isna().all():
            print(f"{col}: Empty column")
        else:
            print(f"{col}: Single unique value - {values[0]}")
else:
    print("No columns with a single unique value or that are entirely empty found.")
# Out:
# C:\Users\casja\AppData\Local\Temp\ipykernel_1032\567622492.py:1: DtypeWarning: Columns (0,8,11,12,13,17,20,21,26,37,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\GitHub\jaar 2\groeps project trein\dataset-prorail-clean-2.csv")
# No columns with a single unique value or that are entirely empty found.

# %%
# Ensure all columns and rows are displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Calculate the total number of rows
total_rows = len(data)

# Create a DataFrame summarizing missing values
missing_values_summary = pd.DataFrame({
    'Column Name': data.columns,
    'Missing Values': data.isnull().sum(),
    'Total Values': total_rows
})

# Calculate the percentage of missing values and round it for readability
missing_values_summary['Percentage Missing'] = ((missing_values_summary['Missing Values'] / missing_values_summary['Total Values']) * 100).round(2)

# Filter to include only columns with missing values
missing_values_summary = missing_values_summary[missing_values_summary['Missing Values'] > 0]

# Print the summary in a more readable format
print("\nMissing Values Summary (Only Columns with Missing Values):\n")
print(missing_values_summary.to_string(index=False, col_space=20))
# Out:
# Missing Values Summary (Only Columns with Missing Values):
#
#                     Column Name       Missing Values         Total Values   Percentage Missing
#                      stm_mon_nr                    1               898526                 0.00
#                     stm_vl_post               588027               898526                65.44
#                stm_sap_meld_ddt                    1               898526                 0.00
#          stm_sap_meldtekst_lang                  140               898526                 0.02
#               stm_sap_meldtekst                 2688               898526                 0.30
#                     stm_geo_mld                21799               898526                 2.43
#               stm_equipm_nr_mld               228252               898526                25.40
#            stm_equipm_soort_mld               236272               898526                26.30
#           stm_equipm_omschr_mld               237166               898526                26.40
#                  stm_km_van_mld                 9437               898526                 1.05
#                  stm_km_tot_mld                 1250               898526                 0.14
#                  stm_prioriteit                  423               898526                 0.05
#                 stm_aanngeb_ddt                35131               898526                 3.91
#                   stm_oh_pg_gst                 8366               898526                 0.93
#                     stm_geo_gst               155749               898526                17.33
#               stm_equipm_nr_gst               285002               898526                31.72
#            stm_equipm_soort_gst               291821               898526                32.48
#           stm_equipm_omschr_gst               292567               898526                32.56
#                  stm_km_van_gst                12411               898526                 1.38
#                  stm_km_tot_gst                 2211               898526                 0.25
#                  stm_oorz_groep                64013               898526                 7.12
#                   stm_oorz_code                55685               898526                 6.20
#                   stm_oorz_tkst               100051               898526                11.14
#                      stm_fh_ddt               184756               898526                20.56
#                   stm_fh_status               156352               898526                17.40
#            stm_sap_storeind_ddt               235134               898526                26.17
#               stm_tao_indicator                10882               898526                 1.21
#        stm_tao_indicator_vorige               548468               898526                61.04
#           stm_tao_soort_mutatie               650860               898526                72.44
#         stm_tao_telling_mutatie                13151               898526                 1.46
# stm_tao_beinvloedbaar_indicator                 3227               898526                 0.36
#               stm_sap_melddatum                  268               898526                 0.03
#                stm_sap_meldtijd                  200               898526                 0.02
#             stm_contractgeb_mld               235343               898526                26.19
#                   stm_techn_mld               224748               898526                25.01
#             stm_contractgeb_gst                10112               898526                 1.13
#                   stm_techn_gst                 3260               898526                 0.36
#                  stm_aanngeb_dd                33730               898526                 3.75
#                stm_aanngeb_tijd                  282               898526                 0.03
#                  stm_aanntpl_dd               199274               898526                22.18
#                stm_aanntpl_tijd                 8226               898526                 0.92
#             stm_progfh_in_datum               311037               898526                34.62
#              stm_progfh_in_tijd                 8761               898526                 0.98
#        stm_progfh_in_invoer_dat               311769               898526                34.70
#       stm_progfh_in_invoer_tijd                 8948               898526                 1.00
#              stm_progfh_in_duur                 1600               898526                 0.18
#              stm_progfh_gw_tijd                19465               898526                 2.17
#            stm_progfh_gw_teller                 4263               898526                 0.47
#                       stm_fh_dd               119302               898526                13.28
#                     stm_fh_tijd                 7205               898526                 0.80
#                     stm_fh_duur                  735               898526                 0.08
#           stm_sap_storeinddatum               227476               898526                25.32
#            stm_sap_storeindtijd                 8375               898526                 0.93
#             stm_oorz_tekst_kort               519353               898526                57.80
#          stm_schade_verhaalb_jn               720015               898526                80.13
#                    stm_pplg_van               641954               898526                71.45
#                   stm_pplg_naar               822533               898526                91.54
#                 stm_dstrglp_van               601949               898526                66.99
#                stm_dstrglp_naar               532530               898526                59.27

# %%
top_n = 20  # Adjust this number as needed
top_incidents = data['stm_sap_meldtekst'].value_counts().nlargest(top_n)
plt.figure(figsize=(10, 6))
sns.barplot(y=top_incidents.index, x=top_incidents.values)
plt.title("Top Incident Types")
plt.xlabel("Count")
plt.ylabel("Incident Type")
plt.show()

# %%
threshold = 100  # Set a threshold for minimum counts
counts = data['stm_sap_meldtekst'].value_counts()

# Apply the lambda function, handling NaN values
data['grouped_incident'] = data['stm_sap_meldtekst'].apply(
    lambda x: x if pd.notna(x) and counts[x] >= threshold else 'Other'
)

# Plot the grouped incident types
plt.figure(figsize=(10, 6))
sns.countplot(y='grouped_incident', data=data)
plt.title("Grouped Incident Types")
plt.xlabel("Count")
plt.ylabel("Incident Type")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', '#stm_sap_meldnr', 'stm_mon_nr', 'stm_vl_post',
#        'stm_sap_meld_ddt', 'stm_sap_meldtekst_lang', 'stm_sap_meldtekst',
#        'stm_geo_mld', 'stm_equipm_nr_mld', 'stm_equipm_soort_mld',
#        'stm_equipm_omschr_mld', 'stm_km_van_mld', 'stm_km_tot_mld',
#        'stm_prioriteit', 'stm_aanngeb_ddt', 'stm_oh_pg_gst', 'stm_geo_gst',
#        'stm_equipm_nr_gst', 'stm_equipm_soort_gst', 'stm_equipm_omschr_gst',
#        'stm_km_van_gst', 'stm_km_tot_gst', 'stm_oorz_groep', 'stm_oorz_code',
#        'stm_oorz_tkst', 'stm_fh_ddt', 'stm_fh_status', 'stm_sap_storeind_ddt',
#        'stm_tao_indicator', 'stm_tao_indicator_vorige',
#        'stm_tao_soort_mutatie', 'stm_tao_telling_mutatie',
#        'stm_tao_beinvloedbaar_indicator', 'stm_sap_melddatum',
#        'stm_sap_meldtijd', 'stm_contractgeb_mld', 'stm_techn_mld',
#        'stm_contractgeb_gst', 'stm_techn_gst', 'stm_aanngeb_dd',
#        'stm_aanngeb_tijd', 'stm_aanntpl_dd', 'stm_aanntpl_tijd',
#        'stm_progfh_in_datum', 'stm_progfh_in_tijd', 'stm_progfh_in_invoer_dat',
#        'stm_progfh_in_invoer_tijd', 'stm_progfh_in_duur', 'stm_progfh_gw_tijd',
#        'stm_progfh_gw_teller', 'stm_fh_dd', 'stm_fh_tijd', 'stm_fh_duur',
#        'stm_sap_storeinddatum', 'stm_sap_storeindtijd', 'stm_oorz_tekst_kort',
#        'stm_schade_verhaalb_jn', 'stm_pplg_van', 'stm_pplg_naar',
#        'stm_dstrglp_van', 'stm_dstrglp_naar', 'grouped_incident'],
#       dtype='object')

# %%
# Convert stm_fh_duur to numeric, setting errors='coerce' will replace non-numeric values with NaN
data['stm_fh_duur'] = pd.to_numeric(data['stm_fh_duur'], errors='coerce')

# Define new bins with 0-14 and 15-29 for the first two ranges, then continue with 30-59, 60-89, etc.
bins = [0, 15, 30] + list(range(60, int(data['stm_fh_duur'].max(skipna=True)) + 30, 30))
labels = ["0-14", "15-29"] + [f"{i}-{i+29}" for i in range(30, int(data['stm_fh_duur'].max(skipna=True)), 30)]

# Create a new column for the binned data
data['stm_fh_duur_grouped'] = pd.cut(data['stm_fh_duur'], bins=bins, labels=labels, right=False)

# Count the occurrences in each bin, dropping NaN values in 'stm_fh_duur_grouped'
grouped_counts = data['stm_fh_duur_grouped'].value_counts().sort_index()

# Set the number of bins to display
n_bins = 10  # Adjust this to control how many bins to display in the chart

# Plot the bar chart
plt.figure(figsize=(12, 6))
grouped_counts.head(n_bins).plot(kind='bar', color='skyblue')
plt.xlabel('Duration Group (stm_fh_duur)')
plt.ylabel('Count')
plt.title('Grouped Duration Count for stm_fh_duur')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
